# %% [markdown]
# ### Assignment 1
#
# #### Session 01
#
# - why should we care about data viz?
#     - helps us to communicate information effectively
#     - want to make sure that we don't miscommunicate the message
#     - helps us to tell our story
# - why bother if we have AI?
#     - we need to be able to interpret what is going on on in the visualization
#     - many ways to visualize, but we need to know the best for context/goal
#
# Classic Examples of Famous Data Visualizations
# - Doctor water pump visualization example
#     - Dr. John Snow decided to visualize deaths and it revealed that the likely source of a disease was through a water system. He shut down the system and it allowed the most effective approach to understand and solve the situation
# - example: causes of mortality of an army
#     - a visualization of mortality revealed what the biggest contributor of death was actually disease, not battle. so they decided to look for changes that could be made in the hospital system, which allowed them to understand what was going on.
#     - the diagram can be difficult to interpret since its the area (not the radius) of the circular diagram
# - example: Minard (1869) - figurative map of the successive losses of men in the French Army int he Russion campaign
#     - shows the size of the army as they moved from Kovno to Moscow.
#     - and then the return journey as well.
#     - it also shows the temperature as well
#     - this allows us connect the size of the army with the distnace travelled and the temperature
#     - can really emphasize how bad the losses were in this entire campaign
# - Challenger Distaster - Tufte's graph
#     - they were ble to show the relationship betweeen the temperature during launches and damage to the o-rings
#     - lower launch temperature is related to greater chance of an incident
#     - though this looks like its really only based on one data point
#     - it was used as a classical example to show this
#     - Robinson identifed errors with this visualization -> it was actually about the ambient temperature.
#         - the argument is that it is actually a bad data visualization since it leads to a bad understanding
#
# - So how do we know if something is a good or bad data visualization? -> an activity:
#     - is the vis nice to look at?
#         - (i disagree with the term nice since this is really subjective)
#     - is it accurate?
#     - what's the message?
#     - overall, is it good or bad?
# - example of Life expectancy 2007:
#     -no its not that nice to look at
#     - unclear accuracy. The scale is unclear. it may not need to start at 0. the title is unclear
#     - the message is that there is lower life expectancy in Africa compared to other continents
#     - not a good figure overall, but passable
#
# - What data vis is:
#     - context: where and how it will be used (academic journal, infographnic, poster)
#     - audience (who is intended to be seen)
#     - data structure - what information do our data capture (quantities, relationships)

# %% [markdown]
# - What tools are used for data vis?
#     - Microsoft Excel
#         - easy to use, but cannot reproduce
#         - easy to connect with other resources
#         - usually first tool to look at data
#     - Tableau
#         - combines data from diffrent sources that are interactive, dynamic on the web
#         - easy to use
#         - industry use cases (infographics for media)
#     - R
#         - programming language for data analysis
#         - free and open source
#         - government and academic uses
#     - Python
#         - programming language
#         - free and open source
#         - requires coding knowledge
#         - used in industry
#     - MatPlotLib
#         - python library
#         - commonly used
#         - free, open source
#         - reproducible
#         - lots of resources online
# - we want to apply our general principles to apply to whichever you use

# %% [markdown]
# #### Slides 02 - Getting Started with Matplotlib

# %% [markdown]
# What is a figure?
#     - a container that holds a set of axies (not the x and y axies but the general canvas)
#     - a figure can hold multiple axes (subplots)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3)) # size is in inches (i.e. 5inches x 3 inches)
ax.scatter(x,y)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)

# %%
# Can you modify our existing code to produce a histogram?
fig, ax = plt.subplots(figsize=(5, 3))
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# %%
fig

# %%
font1 = {'family':'sans-serif','color':'blue','size':20}
font2 = {'family':'monospace','color':'green','size':14}

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_title('Total growth over time', fontdict = font1)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
fig.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y)
ax.set_ylabel('Total growth', fontdict = font2)
ax.set_xlabel('Years since start', fontdict = font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %% [markdown]
# ### Customizing Plot Appearance

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,
y,
marker='*', # NEW ADDITIONS
color = "indigo") # NEW ADDITIONS
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_29304\2403773087.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,
y,
marker='*',
color = 'indigo',
linestyle = '--', # NEW ADDITIONS
linewidth = 2) # NEW ADDITIONS
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_29304\2303017762.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# Colour can be modified. Here is the link to reference the different colours:

# %% [markdown]
# https://matplotlib.org/stable/gallery/color/named_colors.html#sphx-glr-gallery-color-named-colors-py

# %% [markdown]
# We can also use hex codes.

# %%
fig, ax = plt.subplots(figsize=(5, 3))
# color being the new addition
ax.plot(x,y,marker='*', color = '#7425b9', linestyle = '--', linewidth = 2)
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_29304\3198338300.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
ax.plot(x,y,marker='*',
markersize = 12, # NEW ADDITIONS
color = '#7425b9',
linestyle = '--',
linewidth = 2,
markeredgecolor = '#fa9359', # NEW ADDITIONS
markerfacecolor = '#000000' ) # NEW ADDITIONS
fig

# %% [markdown]
# #### Gridlines

# %%
ax.grid(axis = 'y') # this adds gridlines
# Out:
#   Cell In[34], line 1
#     ax.grid(axis = 'y' # this adds gridlines
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# **Activity**: Can you modify the appearance (colour, width, linestyle) of our grid lines
# using what we learned before?

# %%
ax.grid(axis = 'y',
        color = "red", # changes the colour to red
        linestyle = "dotted", # chanes the lines to dotted
        linewidth = 2) # this adds gridlines  # changes the thickness
fig

# %%
# example answer: 

ax.grid(axis = 'y')
ax.grid(axis = 'y', color = "blue", linewidth = 2, linestyle = '-.')
fig

# %% [markdown]
# #### Cheatsheets for Matplotlib
#
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Ch
# eat_Sheet.pdf
# https://github.com/matplotlib/cheatsheets (with beginner, intermediate, and general
# tips versions)

# %% [markdown]
# ### Activity
#
# Visit the Python Graph Gallery at https://python-graph-gallery.com/all-charts/
# Select one of the visualization types that you find most interesting

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Recall the aesthetic , substantive , and perceptual qualities of data
# visualizations. Does your visualization of choice succeed in each area?
#
# - Nice to look at? - It is nice to look at.
# - Accuracy - Unclear if it is accurate since it is example data and does not refer to the accuracy. It commes from the flower dataset built into R, so it likely is following those numbers. Missing a lot of elements like title, axis titles, units, and a legend
# - Message: the message is that the sepal width is greater with higher density.
# - Is it good or bad: I would consider this relatively 'bad' since it is clear to read but is lacking some really important features like a title, axis titles, units, and a legend.
#
# ### Session 2
#
# - US gun killings example figure
#     - shows a visualization that is focused on communicating the number of lives that were cut short and the estimated lifespan if they were not killed.
#     - objectivity and neutrality
#         - it is likely not objective or neutral
#         - since there is a prediction element, it might not be the most objective
#         - wording: stolen, evokes a feeling in the audience
# - Washington Post Active Shooters
#     - is less biased than previous one
#     - likely still tying to tell a story about active shooters increasing
#     - unclear about what active means
#     - deliberately intended to be neutral due to the colour pallette and avoid emotionally charged words
# - NYTimes job report
#     - 2D layout to avoid vs colour
#     - use of arrow to show specific argument
#     - seeing them side by side shows that neither is neutral
#     - it shows that neither are dishonest
#
# - Data visualization cannot be neutral!
#
# - Data Visualizations as Rhetorical Objects
#     - Rhetoric is the act of communicating effectively and persuasively
#     - Since we make choices about how to visualize the data, then the visualizations are not neutral
#     - data visualizations can be factual without being neutral
#     - we should be aware of these decisions and try our best to be factual and communicate our message effectively
#     - perceptual: the rhetoric of the data vis (can we understand the message that the fig is trying to make?)
#
#
# - Intended audience and Intended medium is really important when we consider our visualization
#
# - Different dataset types: (can actually move between each of these different types)
#     - tables
#     - networks (with nodes and links)
#     -  fields (continuous data that covers the entire area - heatmaps)
#     - geometry (objects with coordinates that describes specific things in the geometry - like weather maps)
#     - multidimensional table
#     - trees (like a hierarchical network)
#
# - Effective Visualization
#     - depends on purpose, audience, medium
#     - a good goal to satisfy is to find one of the many possible good soluations rather than one of the even larger number bad ones
#
# - Taking advantage of cognitive psychology: gestalt principles
#     - proximity
#     - similiarity
#     - continuity
#     - closure
#
# - Cognitive load
#     - intrinsic: the intrinsic complexity of new information (cant avoid this)
#     - germane (the audiences familiarty with the information - we should adjust our message and how much data we present and what the audience is expecting)
#     - extraneous (complexity from how the information is presented - we have the most control on this with our decisions)
#
# - Elements that we can control:
#     - familiar vs rare chart types
#     - accurate vs approximate interpretation
#     - concise vs detailed composition
#     - explanatory vs exploratory composition
#
# - Cognition Over memory
#     - don't make people remember the previous data, show both at the same time!
#
# - No 3D without cause
#     - it is hard to understand and increases complexity
#
# - Percieved factual basis
#     - 4 conventions of data visualizations:
#         1. 2d image
#         2. clean layout
#         3. geometric shapes and lines
#         4. inclusion of data sources at bottom of image
#
# Provenance Rhetoric
#     - citing the source
#     - inclusion of data source with graphic signals helps
#
#
# Data Vis Resources:
#  - datavizcatalogue.com
#
#
# Making my own figure: https://python-graph-gallery.com/341-python-gapminder-animation/

# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pandas as pd
import numpy as np

data = pd.read_csv('https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/gapminderData.csv')
data['continent'] = pd.Categorical(data['continent'])
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Subset of the data for year 1952
data1952 = data[data.year == 1952]

# Scatterplot
ax.scatter(
    x = data1952['lifeExp'], 
    y = data1952['gdpPercap'], 
    s = data1952['pop']/50000, 
    c = data1952['continent'].cat.codes, 
    cmap = "Accent", 
    alpha = 0.6, 
    edgecolors = "white", 
    linewidth = 2
)
 
# Add titles (main and on axis)
plt.yscale('log')
ax.set_xlabel("Life Expectancy")
ax.set_ylabel("GDP per Capita")
ax.set_title("Year 1952")
ax.set_ylim(100,50000)
ax.set_xlim(30, 75)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=120)

def update(frame):
    # Clear the current plot to redraw
    ax.clear()
    
    # Filter data for the specific year
    yearly_data = data.loc[data.year == frame, :]

    # Scatter plot for that year
    ax.scatter(
        x=yearly_data['lifeExp'], 
        y=yearly_data['gdpPercap'], 
        s=yearly_data['pop']/100000,
        c=yearly_data['continent'].cat.codes, 
        cmap="Accent", 
        alpha=0.6, 
        edgecolors="white", 
        linewidths=2
    )

    # Updating titles and layout
    ax.set_title(f"Global Development in {frame}")
    ax.set_xlabel("Life Expectancy")
    ax.set_ylabel("GDP per Capita")
    ax.set_yscale('log')
    ax.set_ylim(100, 100000)
    ax.set_xlim(20, 90)

    return ax

ani = FuncAnimation(fig, update, frames=data['year'].unique())
ani.save('gapminder-1.gif', fps=1)

# it does not animate here but will if opened separately.

# %%
interp_data = pd.DataFrame()

multiple = 10
for country in data['country'].unique():
   
   # prepare a temporary dataframe and subset
   temp_df = pd.DataFrame()
   country_df = data[data['country']==country]

   # interpolate the data
   years = np.linspace(country_df['year'].min(), country_df['year'].max(), len(country_df) * multiple-(multiple-1))
   pops = np.linspace(country_df['pop'].min(), country_df['pop'].max(), len(country_df) * multiple-(multiple-1))
   lifeExps = np.linspace(country_df['lifeExp'].min(), country_df['lifeExp'].max(), len(country_df) * multiple-(multiple-1))
   gdps = np.linspace(country_df['gdpPercap'].min(), country_df['gdpPercap'].max(), len(country_df) * multiple-(multiple-1))
   continents = [country_df['continent'].values[0]] * len(years)

   # add the data to the temporary dataframe
   temp_df['year'] = years
   temp_df['pop'] = pops
   temp_df['lifeExp'] = lifeExps
   temp_df['gdpPercap'] = gdps
   temp_df['continent'] = continents
   temp_df['country'] = country

   # append the temporary dataframe to the final dataframe
   interp_data = pd.concat([interp_data, temp_df])
   interp_data['continent'] = pd.Categorical(interp_data['continent'])

interp_data.head()
# Out:
#      year           pop    lifeExp   gdpPercap continent      country
# 0  1952.0  8.425333e+06  28.801000  635.341351      Asia  Afghanistan
# 1  1952.5  8.638647e+06  28.937609  638.456534      Asia  Afghanistan
# 2  1953.0  8.851962e+06  29.074218  641.571716      Asia  Afghanistan
# 3  1953.5  9.065276e+06  29.210827  644.686899      Asia  Afghanistan
# 4  1954.0  9.278591e+06  29.347436  647.802081      Asia  Afghanistan

# %%
fig, ax = plt.subplots(figsize=(10, 10), dpi=120)

def update(frame):
    # Clear the current plot to redraw
    ax.clear()
    
    # Filter data for the specific year
    yearly_data = interp_data.loc[interp_data.year == frame, :]

    # Scatter plot for that year
    ax.scatter(
        x=yearly_data['lifeExp'], 
        y=yearly_data['gdpPercap'], 
        s=yearly_data['pop']/100000,
        c=yearly_data['continent'].cat.codes, 
        cmap="Accent", 
        alpha=0.6, 
        edgecolors="white", 
        linewidths=2
    )

    # Updating titles and layout
    ax.set_title(f"Global Development in {round(frame)}")
    ax.set_xlabel("Life Expectancy")
    ax.set_ylabel("GDP per Capita")
    ax.set_yscale('log')
    ax.set_ylim(100, 100000)
    ax.set_xlim(20, 90)

    return ax

ani = FuncAnimation(fig, update, frames=interp_data['year'].unique())
ani.save('gapminder-2.gif', fps=10)

# %% [markdown]
# # Session 3
#
# ## Reproducibility
# - reproducible work: capable of being checked because the data, code, and methods are available to be shared more easily
# - reproducibility is ethical: helps show the decisions that were made and can help reduce showing bias unintentionally
# - it is not for correctness, and inability to reproduce does not mean that it's incorrect

# %% [markdown]
# - To be reproducible, we should work __programmatically__
# - this means that we can make our images in code and then it means its much easier to reproduce it with the same starting data
# - comment the code to make it clear what is happening

# %% [markdown]
# Slide 05 - Activity

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
# makes the figure 
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\3608551665.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = "Person_1")
ax.plot(x,y2, label = "Person_2")
ax.legend(loc = "lower right") # adds the legend
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\4220221518.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='lower right',
    frameon = True, #add frame around the legend
    fontsize = 12, #change font size
    ncol = 2, #specify number of columns
    shadow = True )
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\444371990.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(
    loc="upper left",
    bbox_to_anchor =(1, 1))
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\3985049513.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(10, 95, "This value is important!")
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\648014557.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(
    10, 95, "This value is important!",
    ha='center', ##alignment of text
    color = 'red', ##modify font colour
    size = 20) ##modify font size
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\4232651755.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])
ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData )
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes )
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure )
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94),
arrowprops=dict(facecolor='black'))
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\2534900723.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate("This is important!",
            xy=(10, 95), xytext=(20, 94),
            arrowprops = dict(arrowstyle = "wedge",
                              color = "hotpink"))
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\221935471.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.yaxis.set_major_locator(plt.NullLocator()) # removes everything on y-axis
ax.xaxis.set_major_formatter(plt.NullFormatter()) # removes the x labels but not ticks

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3)) # sets max number of ticks (3)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xticks(rotation=45, ha='right') # rotate axis labels
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
font1 = {'family':'serif','color':'indigo'}
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %% [markdown]
# Styles
# - convenient way to change many aesthetic dimensions of the plot at once

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# Now we can use one of the themes here.

# %%
plt.style.use('seaborn-v0_8')
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\Prateek\AppData\Local\Temp\ipykernel_39824\3282435145.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### Return to Reproducibility
#
#  - how do we write a good comment?
#     - date, where the data is from, which version it is, description of  the inputs, description of the outputs, concise and clear,
#
#  - FAIR principles
#     - findability: easy to find (with things like DOI)
#     - accessibility: easy to access (data repos to allow access)
#     - interoperability: can be used by others, and with other tools and data formats. This will allow others to access and incorporate the data
#     - resuability: the data can be reused for future studies (clear license with sufficient documentation)
#
#  - Reproducibility vs Replicability vs Reusability
#     - reproducibility and reusability are complimentary
#     - reproducibility is obtaining consistent results with the same data input
#     - replicability obtaining consistent results across studies aimed at answering the same scientific question (each of which obtained its own data) - it also is impacted by random chance
#
#  - Data Practices & Context Documents
#     - data practices are what and how data are collected, managed, used, interpreted, reused, deposited, curated and so on
#     - context documents are intervensions designed to accompany a dataset or ML model, allowing builders to communicate with others
#     - data design and visualization design decisions ca nbe captured in context documents
#     - Datasheets for datasets can help to document the motivation, composition, collection process and recommended uses to facilitate the connections bewteen the underlying data and final analytical products (figures and images in our case)
